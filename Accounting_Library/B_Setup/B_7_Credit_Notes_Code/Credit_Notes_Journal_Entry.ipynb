# %%
import sys
import os
path = os.path.abspath(os.path.join('C:\\Users\\user\\', 'Downloads', 'Convert_pdf_file_into_the_excel_file', 'Rule_Setup', 'Accounting_Library'))
sys.path.append(path)

# %%
# path

# %%
# from A_Rule_Engine.A_1_Ledger_Library import AccountConfiguration
from A_Rule_Engine.A_2_Credit_Note_Journal_Entry import JournalEntryProcessor
import pandas as pd
# Out:
# path ~\Downloads\Convert_pdf_file_into_the_excel_file\Rule_Setup\Accounting_Library\B_Setup\B_1_Ledger_Setup\
# account config file generated successfully

# %%
entry_df = pd.read_excel(path+'\E_Process_2_Accounting\E_Step_1_Common_Template\Sales_Common_Template.xlsx',engine='openpyxl')
config_df = pd.read_excel(path+'\B_Setup\B_1_Ledger_Setup\Output_Ledger_Library.xlsx',engine='openpyxl')

# %%
# print(path+'\B_Setup\B_1_Ledger_Setup\Output_Ledger_Library.xlsx',)

# %%
k  = {
    'J1 - Journal Number':[],
    'J2 - Date' :  [],
    'J3 - Invoice_Ref_Number' : [],
    'J4 - Ledger_Name' : [],
    'J6 - Dr Amount' : [],
    'J7 - Cr Amount' : [],
    'J9 - Description/Narration' : [],
}

# %%
journal_entry = JournalEntryProcessor(entry_df,config_df)

# %%
journal_entry.process_entries(k)
# Out:
# Sales Return
# Enter C3 (Account Name):  AccountsReceivables
# Enter C4 (Sub ledger):  AccountsReceivables
# tax igst 12%
# Enter C3 (Account Name):  AccountsReceivables
# Enter C4 (Sub ledger):  AccountsReceivables
# 600
# tax cgst 12%
# Enter C3 (Account Name):  AccountsReceivables
# Enter C4 (Sub ledger):  AccountsReceivables
# KPMG
# Enter C3 (Account Name):  AccountsReceivables
# Enter C4 (Sub ledger):  AccountsReceivables
# Ledger Name -  Axis Bank A/c
# Enter C3 (Account Name):  AccountsReceivables
# Enter C4 (Sub ledger):  AccountsReceivables
# Ledger Name -  KPMG
# Ledger Name kpmg already present
# Sales Return
# Ledger Name sales return already present
# tax igst 5%
# Enter C3 (Account Name):  AccountsReceivables
# Enter C4 (Sub ledger):  AccountsReceivables
# 375
# tax cgst 5%
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Delloite
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Ledger Name -  Axis Bank A/c
# Ledger Name axis bank a/c already present
# Ledger Name -  Delloite
# Ledger Name delloite already present
# Sales Return
# Ledger Name sales return already present
# tax igst 28%
# Enter C3 (Account Name):  Taxes
# Enter C4 (Sub ledger):  gst
# 3500
# tax cgst 28%
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Capegemini
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Ledger Name -  Axis Bank A/c
# Ledger Name axis bank a/c already present
# Ledger Name -  Capegemini
# Ledger Name capegemini already present
# Sales Return
# Ledger Name sales return already present
# tax igst 12%
# Ledger Name tax igst 12% already present
# 2100
# tax cgst 12%
# Ledger Name tax cgst 12% already present
# SBI
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Ledger Name -  Axis Bank A/c
# Ledger Name axis bank a/c already present
# Ledger Name -  SBI
# Ledger Name sbi already present
# Sales Return
# Ledger Name sales return already present
# tax igst 28%
# Ledger Name tax igst 28% already present
# 5600
# tax cgst 28%
# Ledger Name tax cgst 28% already present
# HDFC
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Ledger Name -  Axis Bank A/c
# Ledger Name axis bank a/c already present
# Ledger Name -  HDFC
# Ledger Name hdfc already present
# Sales Return
# Ledger Name sales return already present
# tax igst 12%
# Ledger Name tax igst 12% already present
# 2400
# tax cgst 12%
# Ledger Name tax cgst 12% already present
# Infosys
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Ledger Name -  Axis Bank A/c
# Ledger Name axis bank a/c already present
# Ledger Name -  Infosys
# Ledger Name infosys already present
# Sales Return
# Ledger Name sales return already present
# tax igst 12%
# Ledger Name tax igst 12% already present
# 3600
# tax cgst 12%
# Ledger Name tax cgst 12% already present
# IBM
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Ledger Name -  Axis Bank A/c
# Ledger Name axis bank a/c already present
# Ledger Name -  IBM
# Ledger Name ibm already present
# Sales Return
# Ledger Name sales return already present
# tax igst 18%
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# tax cgst 18%
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Google
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Ledger Name -  Axis Bank A/c
# Ledger Name axis bank a/c already present
# Ledger Name -  Google
# Ledger Name google already present
# Sales Return
# Ledger Name sales return already present
# tax igst 18%
# Ledger Name tax igst 18% already present
# tax cgst 18%
# Ledger Name tax cgst 18% already present
# Meta
# Enter C3 (Account Name):  Accounts Payable
# Enter C4 (Sub ledger):  Accounts Payable
# Ledger Name -  Axis Bank A/c
# Ledger Name axis bank a/c already present
# Ledger Name -  Meta
# Ledger Name meta already present

# %%
df = pd.DataFrame(k)
df
# Out:
# 44                S008 2024-01-29           AF2223-026875     tax cgst 18%
# 45                S008 2024-01-29           AF2223-026875           Google
# 46               S0088 2024-01-29           AF2223-026875    Axis Bank A/c
# 47               S0088 2024-01-29           AF2223-026875           Google
# 48                S009 2024-01-31           AF2223-026876     Sales Return
# 49                S009 2024-01-31           AF2223-026876     tax igst 18%
# 50                S009 2024-01-31           AF2223-026876     tax cgst 18%
# 51                S009 2024-01-31           AF2223-026876             Meta
# 52               S0099 2024-01-31           AF2223-026876    Axis Bank A/c
# 53               S0099 2024-01-31           AF2223-026876             Meta
#
#     J6 - Dr Amount  J7 - Cr Amount J9 - Description/Narration
# 0            11200               0               Credit Notes
# 1                0            -600               Credit Notes
# 2                0            -600               Credit Notes
# 3                0          -10000               Credit Notes
# 4            11200               0               Credit Notes
# 5                0          -11200               Credit Notes
# 6            15750               0               Credit Notes
# 7                0            -375               Credit Notes
# 8                0            -375               Credit Notes
# 9                0          -15000               Credit Notes
# 10           15750               0               Credit Notes
# 11               0          -15750               Credit Notes
# 12           32000               0               Credit Notes
# 13               0           -3500               Credit Notes
# 14               0           -3500               Credit Notes
# 15               0          -25000               Credit Notes
# 16           32000               0               Credit Notes
# 17               0          -32000               Credit Notes
# 18           39200               0               Credit Notes
# 19               0           -2100               Credit Notes
# 20               0           -2100               Credit Notes
# 21               0          -35000               Credit Notes
# 22           39200               0               Credit Notes
# 23               0          -39200               Credit Notes
# 24           51200               0               Credit Notes
# 25               0           -5600               Credit Notes
# 26               0           -5600               Credit Notes
# 27               0          -40000               Credit Notes
# 28           51200               0               Credit Notes
# 29               0          -51200               Credit Notes
# 30           44800               0               Credit Notes
# 31               0           -2400               Credit Notes
# 32               0           -2400               Credit Notes
# 33               0          -40000               Credit Notes
# 34           44800               0               Credit Notes
# 35               0          -44800               Credit Notes
# 36           67200               0               Credit Notes
# 37               0           -3600               Credit Notes
# 38               0           -3600               Credit Notes
# 39               0          -60000               Credit Notes
# 40           67200               0               Credit Notes
# 41               0          -67200               Credit Notes
# 42          177000               0               Credit Notes
# 43               0          -13500               Credit Notes
# 44               0          -13500               Credit Notes
# 45               0         -150000               Credit Notes
# 46          177000               0               Credit Notes
# 47               0         -177000               Credit Notes
# 48          212400               0               Credit Notes
# 49               0          -16200               Credit Notes
# 50               0          -16200               Credit Notes
# 51               0         -180000               Credit Notes
# 52          212400               0               Credit Notes
# 53               0         -212400               Credit Notes

# %%
file_save_path = 'C:\\Users\\user\\Downloads\\Convert_pdf_file_into_the_excel_file\\Rule_Setup\\Accounting_Library\\E_Process_2_Accounting\\E_Step_2_Journal_Entry\\'
df.to_excel(file_save_path+'Credit_Notes_Journal_Entry_Output.xlsx')
